# %%
# !git clone https://github.com/smritika-sadhukhan/word_embedding.git
# Out:
# Cloning into 'word_embedding'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
pip install -r /content/word_embedding/requirement.txt

# %% [markdown]
# # Training

# %%
# !python /content/word_embedding/train.py --lang hi --model fasttext --size 100 --output data/en_wiki_word2vec_300.txt
# Out:
# [2020-12-09 09:13:09,542] Downloading https://dumps.wikimedia.org/hiwiki/latest/hiwiki-latest-pages-articles-multistream.xml.bz2 to data/hiwiki.xml.bz2
# 100% 171k/171k [00:33<00:00, 5.06kKB/s]
# [2020-12-09 09:13:43,343] Done
# [2020-12-09 09:13:43,343] Parsing wiki corpus
# [2020-12-09 09:13:43,413] adding document #0 to Dictionary(0 unique tokens: [])
# [2020-12-09 09:14:51,859] adding document #10000 to Dictionary(79536 unique tokens: ['or', 'अक', 'अगर', 'अथ', 'अर']...)
# [2020-12-09 09:16:19,602] adding document #20000 to Dictionary(160961 unique tokens: ['or', 'अक', 'अगर', 'अथ', 'अर']...)
# [2020-12-09 09:16:40,689] adding document #30000 to Dictionary(165726 unique tokens: ['or', 'अक', 'अगर', 'अथ', 'अर']...)
# [2020-12-09 09:17:18,096] adding document #40000 to Dictionary(185895 unique tokens: ['or', 'अक', 'अगर', 'अथ', 'अर']...)
# [2020-12-09 09:18:03,763] adding document #50000 to Dictionary(219256 unique tokens: ['or', 'अक', 'अगर', 'अथ', 'अर']...)
# ...

# %% [markdown]
# # **Testing**

# %%
list1=['लगभग','घर']

# %% [markdown]
# # Nearest Neighbour

# %%
from word_embedding import demo
demo.get_nearest_vector(lang='hi',list1=list1,output='/content/data/en_wiki_word2vec_300.txt')
# Out:
# [2020-12-09 11:26:11,375] Loading word vector
# [2020-12-09 11:26:12,361] Nearest words of लगभग
# [2020-12-09 11:26:12,362] word आसप score 0.775407
# [2020-12-09 11:26:12,363] word जनसख score 0.719018
# [2020-12-09 11:26:12,365] word यह score 0.716926
# [2020-12-09 11:26:12,368] word लगभ score 0.706087
# [2020-12-09 11:26:12,369] word आब score 0.693523
# [2020-12-09 11:26:12,391] Nearest words of घर
# [2020-12-09 11:26:12,392] word अत score 0.788641
# [2020-12-09 11:26:12,392] word कप score 0.745530
# [2020-12-09 11:26:12,394] word रहन score 0.667001
# [2020-12-09 11:26:12,395] word टल score 0.654928
# [2020-12-09 11:26:12,397] word और score 0.649775

# %% [markdown]
# # Vector

# %%
demo.get_vectors(lang='hi',word='लगभग',output='/content/data/en_wiki_word2vec_300.txt')
# Out:
# [2020-12-09 11:26:12,411] Loading word vector
# array([[ 0.22898893,  0.12985307, -0.0084189 ,  0.15049602, -0.08906563,
#         -0.25100002,  0.20384355,  0.08355643,  0.00543702,  0.47362795,
#         -0.3917939 , -0.1262673 ,  0.40402272,  0.03777381, -0.20161414,
#         -0.029909  ,  0.09512483,  0.16250943,  0.13604207,  0.14691295,
#         -0.0726165 , -0.3130461 ,  0.2513811 , -0.14386559, -0.24612036,
#          0.11036651,  0.20616975, -0.08760805,  0.0170586 ,  0.01643924,
#         -0.27328548, -0.1078749 ,  0.00274878, -0.44497165,  0.2923321 ,
#          0.20620812, -0.10749883, -0.01913645,  0.03331033, -0.01392101,
#          0.13321933,  0.23704857,  0.34085557, -0.07784275,  0.06875449,
#          0.11351301,  0.08075167, -0.32889768, -0.07248501, -0.27766803,
#          0.00754017,  0.3645911 , -0.26069653, -0.0997327 , -0.14836903,
#         -0.11313453, -0.02067145,  0.16443245, -0.23126961, -0.21377401,
# ...
